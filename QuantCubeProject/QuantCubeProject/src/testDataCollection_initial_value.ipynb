# %% [markdown]
# # QuantCube GDP Nowcasting — Data Pipeline & Diagnostics

# %% [markdown]
# ## 1. Environment setup
#
# The notebook expects the project structure:
#
# ```text
# QuantCubeProject/
# ├── data/
# │   ├── raw/
# │   └── processed/
# ├── notebooks/
# └── src/
#     ├── DataCollection.py
#     ├── DataProcessing.py
#     ├── DataAnalysis.py
#     ├── DataSplitter.py
#     ├── TrainingModels.py
#     ├── AnalyseModels.py
#     └── config.py
# ```
#
# The code below automatically finds the project root whether the notebook is launched from the root or from `notebooks/`.

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 160)

#--- fetch paths ---

cwd = Path.cwd()

if (cwd / "src").exists():
    PROJECT_ROOT = cwd
elif (cwd.parent / "src").exists():
    PROJECT_ROOT = cwd.parent
else:
    raise FileNotFoundError(
        "Could not find the project root. Expected a 'src/' directory "
        "in the current directory or its parent."
    )

SRC_DIR = PROJECT_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

print("Project root:", PROJECT_ROOT)
print("Source dir   :", SRC_DIR)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project root: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject
# Source dir   : /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/src

# %%
#--- class import ---

import config
import DataCollection
import DataProcessing
import DataAnalysis
import DataSplitter

# %% [markdown]
# ## 2. Run configuration

# %%
OBSERVATION_START = "1990-01-01"
LOOKBACK_QUARTERS = 3
TEST_SIZE = 0.1

REFRESH_RAW_FEATURES = False

RAW_DIR = PROJECT_ROOT / "data" / "raw"
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

RAW_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

FRED_API_KEY = "YOUR_API_KEY"

if not FRED_API_KEY:
    raise ValueError(
        "FRED_API_KEY is not set. Set it in your environment before running this notebook."
    )

datacollect = DataCollection.DataCollection(
    api_key_fed=FRED_API_KEY
)

print("Observation start :", OBSERVATION_START)
print("Lookback quarters :", LOOKBACK_QUARTERS)
print("Test size         :", TEST_SIZE)
print("Refresh raw data  :", REFRESH_RAW_FEATURES)
# Out:
# Observation start : 1990-01-01
# Lookback quarters : 3
# Test size         : 0.1
# Refresh raw data  : False

# %% [markdown]
# ## 3. GDP release calendar and original label
#
# Collect the **initial GDP release calendar**, and the **Labels**

# %%
calendar = datacollect.get_release_dates(
    series_id="GDPC1",
    observation_start=OBSERVATION_START
)

calendar = datacollect.build_initial_gdp_growth()

print(
    "Calendar shape:",
    calendar.shape
)

print(
    "Quarter range:",
    calendar["quarter"].iloc[0],
    "->",
    calendar["quarter"].iloc[-1]
)

display(
    calendar.head()
)

display(
    calendar.tail()
)

release_lags = (
    calendar["release_lag_days"]
    .dropna()
)

print("\nGDP release lag summary:")

display(
    release_lags
    .describe(
        percentiles=[
            0.01,
            0.05,
            0.10,
            0.25,
            0.50,
            0.75,
            0.90,
            0.95,
            0.99
        ]
    )
)

quantiles = (
    release_lags
    .quantile(
        [
            0.01,
            0.05,
            0.10,
            0.25,
            0.50,
            0.75,
            0.90,
            0.95,
            0.99
        ]
    )
    .rename("release_lag_days")
    .to_frame()
)

quantiles.index = [
    "1%",
    "5%",
    "10%",
    "25%",
    "50%",
    "75%",
    "90%",
    "95%",
    "99%"
]

print("\nRelease lag quantiles:")

display(
    quantiles
)


# ==================================================
# Distribution
# ==================================================

plt.figure(
    figsize=(10, 5)
)

plt.hist(
    release_lags,
    bins=20,
    edgecolor="black"
)

plt.axvline(
    release_lags.median(),
    linestyle="--",
    label=(
        f"Median = "
        f"{release_lags.median():.0f} days"
    )
)

plt.xlabel(
    "Days between quarter end and GDP release"
)

plt.ylabel(
    "Number of quarters"
)

plt.title(
    "Distribution of Initial GDP Release Lag"
)

plt.legend()

plt.show()
# Out:
# GDP release calendar saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/raw/calendar_gdp_release_dates.csv
# Get GDP values for 1991Q4 | release 1992-01-29
# Get GDP values for 1992Q1 | release 1992-04-28
# Get GDP values for 1992Q2 | release 1992-07-30
# Get GDP values for 1992Q3 | release 1992-10-27
# Get GDP values for 1992Q4 | release 1993-01-28
# Get GDP values for 1993Q1 | release 1993-04-29
# Get GDP values for 1993Q2 | release 1993-07-29
# Get GDP values for 1993Q3 | release 1993-10-28
# Get GDP values for 1993Q4 | release 1994-01-28
# Get GDP values for 1994Q1 | release 1994-04-28
# Get GDP values for 1994Q2 | release 1994-07-29
# Get GDP values for 1994Q3 | release 1994-10-28
# Get GDP values for 1994Q4 | release 1995-01-27
# Get GDP values for 1995Q1 | release 1995-04-28
# Get GDP values for 1995Q2 | release 1995-07-28
# Get GDP values for 1995Q3 | release 1995-10-27
# Get GDP values for 1995Q4 | release 1996-02-23
# Get GDP values for 1996Q1 | release 1996-05-02
# Get GDP values for 1996Q2 | release 1996-08-01
# Get GDP values for 1996Q3 | release 1996-10-30
# Get GDP values for 1996Q4 | release 1997-01-31
# Get GDP values for 1997Q1 | release 1997-04-30
# Get GDP values for 1997Q2 | release 1997-07-31
# Get GDP values for 1997Q3 | release 1997-10-31
# Get GDP values for 1997Q4 | release 1998-01-30
# Get GDP values for 1998Q1 | release 1998-04-30
# Get GDP values for 1998Q2 | release 1998-07-31
# Get GDP values for 1998Q3 | release 1998-10-30
# Get GDP values for 1998Q4 | release 1999-01-29
# Get GDP values for 1999Q1 | release 1999-04-30
# Get GDP values for 1999Q2 | release 1999-07-29
# Get GDP values for 1999Q3 | release 1999-10-28
# Get GDP values for 1999Q4 | release 2000-01-28
# Get GDP values for 2000Q1 | release 2000-04-27
# Get GDP values for 2000Q2 | release 2000-07-28
# Get GDP values for 2000Q3 | release 2000-10-27
# Get GDP values for 2000Q4 | release 2001-01-31
# Get GDP values for 2001Q1 | release 2001-04-27
# Get GDP values for 2001Q2 | release 2001-07-27
# Get GDP values for 2001Q3 | release 2001-10-31
# Get GDP values for 2001Q4 | release 2002-01-30
# Get GDP values for 2002Q1 | release 2002-04-26
# Get GDP values for 2002Q2 | release 2002-07-31
# Get GDP values for 2002Q3 | release 2002-10-31
# Get GDP values for 2002Q4 | release 2003-01-30
# Get GDP values for 2003Q1 | release 2003-04-25
# Get GDP values for 2003Q2 | release 2003-07-31
# Get GDP values for 2003Q3 | release 2003-10-30
# Get GDP values for 2003Q4 | release 2004-01-30
# Get GDP values for 2004Q1 | release 2004-04-29
# Get GDP values for 2004Q2 | release 2004-07-30
# Get GDP values for 2004Q3 | release 2004-10-29
# Get GDP values for 2004Q4 | release 2005-01-28
# Get GDP values for 2005Q1 | release 2005-04-28
# Get GDP values for 2005Q2 | release 2005-07-29
# Get GDP values for 2005Q3 | release 2005-10-28
# Get GDP values for 2005Q4 | release 2006-01-27
# Get GDP values for 2006Q1 | release 2006-04-28
# Get GDP values for 2006Q2 | release 2006-07-28
# Get GDP values for 2006Q3 | release 2006-10-27
# Get GDP values for 2006Q4 | release 2007-01-31
# Get GDP values for 2007Q1 | release 2007-04-27
# Get GDP values for 2007Q2 | release 2007-07-27
# Get GDP values for 2007Q3 | release 2007-10-31
# Get GDP values for 2007Q4 | release 2008-01-30
# Get GDP values for 2008Q1 | release 2008-04-30
# Get GDP values for 2008Q2 | release 2008-07-31
# Get GDP values for 2008Q3 | release 2008-10-30
# Get GDP values for 2008Q4 | release 2009-01-30
# Get GDP values for 2009Q1 | release 2009-04-29
# Get GDP values for 2009Q2 | release 2009-07-31
# Get GDP values for 2009Q3 | release 2009-10-29
# Get GDP values for 2009Q4 | release 2010-01-29
# Get GDP values for 2010Q1 | release 2010-04-30
# Get GDP values for 2010Q2 | release 2010-07-30
# Get GDP values for 2010Q3 | release 2010-10-29
# Get GDP values for 2010Q4 | release 2011-01-28
# Get GDP values for 2011Q1 | release 2011-04-28
# Get GDP values for 2011Q2 | release 2011-07-29
# Get GDP values for 2011Q3 | release 2011-10-27
# Get GDP values for 2011Q4 | release 2012-01-27
# Get GDP values for 2012Q1 | release 2012-04-27
# Get GDP values for 2012Q2 | release 2012-07-27
# Get GDP values for 2012Q3 | release 2012-10-26
# Get GDP values for 2012Q4 | release 2013-01-30
# Get GDP values for 2013Q1 | release 2013-04-26
# Get GDP values for 2013Q2 | release 2013-07-31
# Get GDP values for 2013Q3 | release 2013-11-07
# Get GDP values for 2013Q4 | release 2014-01-30
# Get GDP values for 2014Q1 | release 2014-04-30
# Get GDP values for 2014Q2 | release 2014-07-30
# Get GDP values for 2014Q3 | release 2014-10-30
# Get GDP values for 2014Q4 | release 2015-01-30
# Get GDP values for 2015Q1 | release 2015-04-29
# Get GDP values for 2015Q2 | release 2015-07-30
# Get GDP values for 2015Q3 | release 2015-10-29
# Get GDP values for 2015Q4 | release 2016-01-29
# Get GDP values for 2016Q1 | release 2016-04-28
# Get GDP values for 2016Q2 | release 2016-07-29
# Get GDP values for 2016Q3 | release 2016-10-28
# Get GDP values for 2016Q4 | release 2017-01-27
# Get GDP values for 2017Q1 | release 2017-04-28
# Get GDP values for 2017Q2 | release 2017-07-28
# Get GDP values for 2017Q3 | release 2017-10-27
# Get GDP values for 2017Q4 | release 2018-01-26
# Get GDP values for 2018Q1 | release 2018-04-27
# Get GDP values for 2018Q2 | release 2018-07-27
# Get GDP values for 2018Q3 | release 2018-10-26
# Get GDP values for 2018Q4 | release 2019-02-28
# Get GDP values for 2019Q1 | release 2019-04-26
# Get GDP values for 2019Q2 | release 2019-07-26
# Get GDP values for 2019Q3 | release 2019-10-30
# Get GDP values for 2019Q4 | release 2020-01-30
# Get GDP values for 2020Q1 | release 2020-04-29
# Get GDP values for 2020Q2 | release 2020-07-30
# Get GDP values for 2020Q3 | release 2020-10-29
# Get GDP values for 2020Q4 | release 2021-01-28
# Get GDP values for 2021Q1 | release 2021-04-29
# Get GDP values for 2021Q2 | release 2021-07-29
# Get GDP values for 2021Q3 | release 2021-10-28
# Get GDP values for 2021Q4 | release 2022-01-27
# Get GDP values for 2022Q1 | release 2022-04-28
# Get GDP values for 2022Q2 | release 2022-07-28
# Get GDP values for 2022Q3 | release 2022-10-27
# Get GDP values for 2022Q4 | release 2023-01-26
# Get GDP values for 2023Q1 | release 2023-04-27
# Get GDP values for 2023Q2 | release 2023-07-27
# Get GDP values for 2023Q3 | release 2023-10-26
# Get GDP values for 2023Q4 | release 2024-01-25
# Get GDP values for 2024Q1 | release 2024-04-25
# Get GDP values for 2024Q2 | release 2024-07-25
# Get GDP values for 2024Q3 | release 2024-10-30
# Get GDP values for 2024Q4 | release 2025-01-30
# Get GDP values for 2025Q1 | release 2025-04-30
# Get GDP values for 2025Q2 | release 2025-07-30
# Get GDP values for 2025Q3 | release 2025-12-23
# Get GDP values for 2025Q4 | release 2026-02-20
# Get GDP values for 2026Q1 | release 2026-04-30
# Get GDP values for 2026Q2 | release 2026-07-30
# GDP calendar saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/raw/calendar_gdp.csv
# Cutoff horizon: 18 days after quarter-end
# Calendar shape: (139, 9)
# Quarter range: 1991Q4 -> 2026Q2
#   quarter quarter_start quarter_end release_date  release_lag_days  initial_value  initial_growth  quarterly_ratio cutoff_date
# 0  1991Q4    1991-10-01  1991-12-31   1992-01-29                29       1.000000        0.296461         1.000740  1992-01-18
# 1  1992Q1    1992-01-01  1992-03-31   1992-04-28                28       1.004910        1.978356         1.004910  1992-04-18
# 2  1992Q2    1992-04-01  1992-06-30   1992-07-30                30       1.008374        1.385975         1.003447  1992-07-18
# 3  1992Q3    1992-07-01  1992-09-30   1992-10-27                27       1.014990        2.650422         1.006561  1992-10-18
# 4  1992Q4    1992-10-01  1992-12-31   1993-01-28                28       1.024474        3.790272         1.009344  1993-01-18
#     quarter quarter_start quarter_end release_date  release_lag_days  initial_value  initial_growth  quarterly_ratio cutoff_date
# 134  2025Q2    2025-04-01  2025-06-30   2025-07-30                30       2.190862        2.968252         1.007339  2025-07-18
# 135  2025Q3    2025-07-01  2025-09-30   2025-12-23                84       2.214270        4.342784         1.010685  2025-10-18
# 136  2025Q4    2025-10-01  2025-12-31   2026-02-20                51       2.222103        1.422544         1.003538  2026-01-18
# 137  2026Q1    2026-01-01  2026-03-31   2026-04-30                30       2.233075        1.989722         1.004938  2026-04-18
# 138  2026Q2    2026-04-01  2026-06-30   2026-07-30                30       2.241403        1.500152         1.003729  2026-07-18
# GDP release lag summary:
# count    139.000000
# mean      29.676259
# std        6.268412
# min       25.000000
# 1%        25.000000
# 5%        26.000000
# 10%       27.000000
# 25%       27.000000
# 50%       29.000000
# 75%       30.000000
# 90%       31.000000
# 95%       31.100000
# 99%       57.100000
# max       84.000000
# Name: release_lag_days, dtype: float64
# Release lag quantiles:
#      release_lag_days
# 1%               25.0
# 5%               26.0
# 10%              27.0
# 25%              27.0
# 50%              29.0
# 75%              30.0
# 90%              31.0
# 95%              31.1
# 99%              57.1

# %%
print(calendar)
# Out:
#     quarter quarter_start quarter_end release_date  release_lag_days  initial_value  initial_growth  quarterly_ratio cutoff_date
# 0    1991Q4    1991-10-01  1991-12-31   1992-01-29                29       1.000000        0.296461         1.000740  1992-01-18
# 1    1992Q1    1992-01-01  1992-03-31   1992-04-28                28       1.004910        1.978356         1.004910  1992-04-18
# 2    1992Q2    1992-04-01  1992-06-30   1992-07-30                30       1.008374        1.385975         1.003447  1992-07-18
# 3    1992Q3    1992-07-01  1992-09-30   1992-10-27                27       1.014990        2.650422         1.006561  1992-10-18
# 4    1992Q4    1992-10-01  1992-12-31   1993-01-28                28       1.024474        3.790272         1.009344  1993-01-18
# ..      ...           ...         ...          ...               ...            ...             ...              ...         ...
# 134  2025Q2    2025-04-01  2025-06-30   2025-07-30                30       2.190862        2.968252         1.007339  2025-07-18
# 135  2025Q3    2025-07-01  2025-09-30   2025-12-23                84       2.214270        4.342784         1.010685  2025-10-18
# 136  2025Q4    2025-10-01  2025-12-31   2026-02-20                51       2.222103        1.422544         1.003538  2026-01-18
# 137  2026Q1    2026-01-01  2026-03-31   2026-04-30                30       2.233075        1.989722         1.004938  2026-04-18
# 138  2026Q2    2026-04-01  2026-06-30   2026-07-30                30       2.241403        1.500152         1.003729  2026-07-18
#
# [139 rows x 9 columns]

# %%
calendar_checks = pd.DataFrame({
    "metric": [
        "number_of_quarters",
        "missing_release_dates",
        "missing_initial_values",
        "duplicate_quarters",
        "missing_initial_growth",
        "min_release_lag_days",
        "median_release_lag_days",
        "max_release_lag_days",
    ],
    "value": [
        len(calendar),
        calendar["release_date"].isna().sum(),
        calendar["initial_value"].isna().sum(),
        calendar["quarter"].duplicated().sum(),
        calendar["initial_growth"].isna().sum(),
        calendar["release_lag_days"].min(),
        calendar["release_lag_days"].median(),
        calendar["release_lag_days"].max(),
    ]
})

display(calendar_checks)
# Out:
#                     metric  value
# 0       number_of_quarters  139.0
# 1    missing_release_dates    0.0
# 2   missing_initial_values    0.0
# 3       duplicate_quarters    0.0
# 4   missing_initial_growth    0.0
# 5     min_release_lag_days   25.0
# 6  median_release_lag_days   29.0
# 7     max_release_lag_days   84.0

# %% [markdown]
# We observe no missing labels

# %%
# Time-series view of the original initial GDP releases.

plt.figure(figsize=(12, 4))

plt.plot(
    pd.to_datetime(calendar["quarter_end"]),
    calendar["initial_value"]
)

plt.title("Initial-release real GDP level")
plt.xlabel("Quarter")
plt.ylabel("Initial GDP level")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Raw point-in-time feature snapshots
#
# Each snapshot must represent **only information available at that cutoff_date**.
#
# For every cutoff date, the raw file contains the historical observations of every FRED feature as known on that date.

# %%
RAW_FEATURES_PATH = RAW_DIR / "raw_features.pkl"
FORCE_RECOLT = False

if FORCE_RECOLT:
    snapshots = datacollect.get_features_by_cutoff(
            calendar=calendar,
            fred_features=config.FRED_FEATURES,
            lookback_quarters=LOOKBACK_QUARTERS
        )
else:

    if REFRESH_RAW_FEATURES or not RAW_FEATURES_PATH.exists():

        snapshots = datacollect.get_features_by_cutoff(
            calendar=calendar,
            fred_features=config.FRED_FEATURES,
            lookback_quarters=LOOKBACK_QUARTERS
        )

    else:

        snapshots = pd.read_pickle(
            RAW_FEATURES_PATH
        )

        print(
            "Loaded existing raw snapshots from:",
            RAW_FEATURES_PATH
        )

    print("Number of cutoff snapshots:", len(snapshots))

if snapshots:
    snapshot_dates = sorted(pd.to_datetime(list(snapshots.keys())))
    print("First cutoff:", snapshot_dates[0].date())
    print("Last cutoff :", snapshot_dates[-1].date())
# Out:
# Loaded existing raw snapshots from: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/raw/raw_features.pkl
# Number of cutoff snapshots: 139
# First cutoff: 1992-01-18
# Last cutoff : 2026-07-18

# %%
latest_cutoff = max(snapshots.keys())
latest_snapshot = snapshots[latest_cutoff].copy()

print("Latest cutoff       :", pd.Timestamp(latest_cutoff).date())
print("Raw rows            :", len(latest_snapshot))
print("Number of series    :", latest_snapshot["series_id"].nunique())
print("Missing raw values  :", latest_snapshot["value"].isna().sum())

display(latest_snapshot.head(20))
# Out:
# Latest cutoff       : 2026-07-18
# Raw rows            : 237
# Number of series    : 21
# Missing raw values  : 1
#    observation_date realtime_start realtime_end     value cutoff_date quarter_end series_id              feature_name
# 0        2025-10-01     2026-07-18   2026-07-18  605401.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 1        2025-11-01     2026-07-18   2026-07-18  621859.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 2        2025-12-01     2026-07-18   2026-07-18  619137.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 3        2026-01-01     2026-07-18   2026-07-18  619352.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 4        2026-02-01     2026-07-18   2026-07-18  621304.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 5        2026-03-01     2026-07-18   2026-07-18  632650.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 6        2026-04-01     2026-07-18   2026-07-18  665895.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 7        2026-05-01     2026-07-18   2026-07-18  657373.0  2026-07-18  2026-06-30    AMTMNO  manufacturing_new_orders
# 8        2025-10-01     2026-07-18   2026-07-18   77817.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 9        2025-11-01     2026-07-18   2026-07-18   78015.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 10       2025-12-01     2026-07-18   2026-07-18   78767.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 11       2026-01-01     2026-07-18   2026-07-18   78752.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 12       2026-02-01     2026-07-18   2026-07-18   79769.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 13       2026-03-01     2026-07-18   2026-07-18   80833.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 14       2026-04-01     2026-07-18   2026-07-18   81292.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 15       2026-05-01     2026-07-18   2026-07-18   81383.0  2026-07-18  2026-06-30    ANXAVS   capital_goods_shipments
# 16       2025-10-01     2026-07-18   2026-07-18  301158.0  2026-07-18  2026-06-30   BOPTEXP                   exports
# 17       2025-11-01     2026-07-18   2026-07-18  289504.0  2026-07-18  2026-06-30   BOPTEXP                   exports
# 18       2025-12-01     2026-07-18   2026-07-18  285282.0  2026-07-18  2026-06-30   BOPTEXP                   exports
# 19       2026-01-01     2026-07-18   2026-07-18  299806.0  2026-07-18  2026-06-30   BOPTEXP                   exports

# %% [markdown]
# ## 6. Inspect the preprocessing assumptions
#
# Before transforming the data, inspect both:
#
# 1. the FRED metadata for every feature, and
# 2. the transformation rules used by `PREPROCESSING_CONFIG`.
#
# This makes it easier to catch an inappropriate log transformation, frequency mismatch, or unexpected unit.

# %%
fred_metadata = datacollect.build_preprocessing_config(
    config.FRED_FEATURES
)

fred_metadata_df = (
    pd.DataFrame
    .from_dict(
        fred_metadata,
        orient="index"
    )
    .rename_axis("series_id")
    .reset_index()
)

display(fred_metadata_df)
# Out:
#      series_id                 feature_name frequency                             units seasonal_adjustment
# 0       PCEC96                     real_pce         M  Billions of Chained 2017 Dollars                SAAR
# 1        RSAFS                 retail_sales         M               Millions of Dollars                  SA
# 2      TOTALSA                vehicle_sales         M                 Millions of Units                SAAR
# 3      DSPIC96       real_disposable_income         M  Billions of Chained 2017 Dollars                SAAR
# 4        HOUST               housing_starts         M                Thousands of Units                SAAR
# 5       PERMIT             building_permits         M                Thousands of Units                SAAR
# 6    TLRESCONS     residential_construction         M               Millions of Dollars                SAAR
# 7       ANXAVS      capital_goods_shipments         M               Millions of Dollars                  SA
# 8   TLNRESCONS  nonresidential_construction         M               Millions of Dollars                SAAR
# 9       AMTMNO     manufacturing_new_orders         M               Millions of Dollars                  SA
# 10      BUSINV         business_inventories         M               Millions of Dollars                  SA
# 11     BOPTEXP                      exports         M               Millions of Dollars                  SA
# 12     BOPTIMP                      imports         M               Millions of Dollars                  SA
# 13   TLPBLCONS          public_construction         M               Millions of Dollars                SAAR
# 14      INDPRO        industrial_production         M                    Index 2017=100                  SA
# 15      PAYEMS             nonfarm_payrolls         M              Thousands of Persons                  SA
# 16        ICSA               initial_claims         W                            Number                  SA
# 17       PCEPI              pce_price_index         M                    Index 2017=100                  SA
# 18    CPIAUCSL                          cpi         M               Index 1982-1984=100                  SA
# 19       CFNAI      national_activity_index         M                             Index                 NSA
# 20        NFCI         financial_conditions         W                             Index                 NSA

# %%
preprocessing_rules_df = (
    pd.DataFrame
    .from_dict(
        config.PREPROCESSING_CONFIG,
        orient="index"
    )
    .rename_axis("series_id")
    .reset_index()
)

display(preprocessing_rules_df)
# Out:
#      series_id                 feature_name frequency                             units seasonal_adjustment   transform     windows
# 0       PCEC96                     real_pce         M  Billions of Chained 2017 Dollars                SAAR  log_growth      [1, 3]
# 1        RSAFS                 retail_sales         M               Millions of Dollars                  SA  log_growth      [1, 3]
# 2      TOTALSA                vehicle_sales         M                 Millions of Units                SAAR  log_growth      [1, 3]
# 3      DSPIC96       real_disposable_income         M  Billions of Chained 2017 Dollars                SAAR  log_growth      [1, 3]
# 4        HOUST               housing_starts         M                Thousands of Units                SAAR  log_growth      [1, 3]
# 5       PERMIT             building_permits         M                Thousands of Units                SAAR  log_growth      [1, 3]
# 6    TLRESCONS     residential_construction         M               Millions of Dollars                SAAR  log_growth      [1, 3]
# 7       ANXAVS      capital_goods_shipments         M               Millions of Dollars                  SA  log_growth      [1, 3]
# 8   TLNRESCONS  nonresidential_construction         M               Millions of Dollars                SAAR  log_growth      [1, 3]
# 9       AMTMNO     manufacturing_new_orders         M               Millions of Dollars                  SA  log_growth      [1, 3]
# 10      BUSINV         business_inventories         M               Millions of Dollars                  SA  difference      [1, 3]
# 11     BOPTEXP                      exports         M               Millions of Dollars                  SA  log_growth      [1, 3]
# 12     BOPTIMP                      imports         M               Millions of Dollars                  SA  log_growth      [1, 3]
# 13   TLPBLCONS          public_construction         M               Millions of Dollars                SAAR  log_growth      [1, 3]
# 14      INDPRO        industrial_production         M                    Index 2017=100                  SA  log_growth      [1, 3]
# 15      PAYEMS             nonfarm_payrolls         M              Thousands of Persons                  SA  difference      [1, 3]
# 16        ICSA               initial_claims         W                            Number                  SA  level_mean  [1, 4, 13]
# 17       PCEPI              pce_price_index         M                    Index 2017=100                  SA  log_growth      [1, 3]
# 18    CPIAUCSL                          cpi         M               Index 1982-1984=100                  SA  log_growth      [1, 3]
# 19       CFNAI      national_activity_index         M                             Index                 NSA  level_mean      [1, 3]
# 20        NFCI         financial_conditions         W                             Index                 NSA  level_mean  [1, 4, 13]

# %% [markdown]
# ## 7. Raw-data diagnostics
#
# This stage answers:
#
# - Which series are historically available?
# - Which series have missing raw observations?
# - When does coverage begin?
# - Does the latest cutoff look sensible?
#
# These checks happen **before feature engineering**.

# %% [markdown]
# ## 8. Build processed features
#
# Now transform the raw snapshots into one feature row per quarter-end cutoff.

# %%
dataprocess = DataProcessing.DataProcessing()

features = dataprocess.build_features()
features = dataprocess.features_cleaning()

if features is None:
    features = pd.read_csv(
        dataprocess.processed_features_path,
        parse_dates=["cutoff_date"]
    )

if features.index.name == "cutoff_date":
    features_for_merge = features.reset_index()
else:
    features_for_merge = features.copy()
    features_for_merge["cutoff_date"] = pd.to_datetime(
        features_for_merge["cutoff_date"]
    )

features_for_merge = (
    features_for_merge
    .sort_values("cutoff_date")
    .reset_index(drop=True)
)

print("Processed feature matrix shape:", features_for_merge.shape)
print(
    "Feature date range:",
    features_for_merge["cutoff_date"].min(),
    "->",
    features_for_merge["cutoff_date"].max()
)

display(features_for_merge.head())
display(features_for_merge.tail())
# Out:
# features to dropp ; ['building_permits_growth_1', 'building_permits_growth_3', 'pce_price_index_growth_1', 'pce_price_index_growth_3', 'retail_sales_growth_1', 'retail_sales_growth_3', 'initial_claims_mean_1', 'initial_claims_mean_4', 'initial_claims_mean_13', 'exports_growth_1', 'exports_growth_3', 'imports_growth_1', 'imports_growth_3', 'residential_construction_growth_1', 'residential_construction_growth_3', 'capital_goods_shipments_growth_1', 'capital_goods_shipments_growth_3', 'nonresidential_construction_growth_1', 'nonresidential_construction_growth_3', 'manufacturing_new_orders_growth_1', 'manufacturing_new_orders_growth_3', 'public_construction_growth_1', 'public_construction_growth_3', 'national_activity_index_mean_1', 'national_activity_index_mean_3', 'financial_conditions_mean_1', 'financial_conditions_mean_4', 'financial_conditions_mean_13', 'vehicle_sales_growth_1', 'vehicle_sales_growth_3']
# Original features: 49
# Dropped features: 30
# Remaining features: 19
#
# Dropped because of missingness:
# building_permits_growth_1: 22.30%
# building_permits_growth_3: 22.30%
# pce_price_index_growth_1: 25.18%
# pce_price_index_growth_3: 25.18%
# retail_sales_growth_1: 27.34%
# retail_sales_growth_3: 27.34%
# initial_claims_mean_1: 50.36%
# initial_claims_mean_4: 50.36%
# initial_claims_mean_13: 50.36%
# exports_growth_1: 52.52%
# exports_growth_3: 52.52%
# imports_growth_1: 52.52%
# imports_growth_3: 52.52%
# residential_construction_growth_1: 56.12%
# residential_construction_growth_3: 56.12%
# capital_goods_shipments_growth_1: 56.12%
# capital_goods_shipments_growth_3: 56.12%
# nonresidential_construction_growth_1: 56.12%
# nonresidential_construction_growth_3: 56.12%
# manufacturing_new_orders_growth_1: 56.12%
# manufacturing_new_orders_growth_3: 56.12%
# public_construction_growth_1: 56.12%
# public_construction_growth_3: 56.12%
# national_activity_index_mean_1: 56.12%
# national_activity_index_mean_3: 56.12%
# financial_conditions_mean_1: 56.12%
# financial_conditions_mean_4: 56.12%
# financial_conditions_mean_13: 56.12%
# vehicle_sales_growth_1: 61.15%
# vehicle_sales_growth_3: 61.15%
# Processed feature matrix shape: (139, 19)
# Feature date range: 1992-01-18 00:00:00 -> 2026-07-18 00:00:00
#   cutoff_date  real_pce_growth_1  real_pce_growth_3  real_disposable_income_growth_1  real_disposable_income_growth_3  housing_starts_growth_1  \
# 0  1992-01-18           0.360790           0.287304                        -0.451991                        -0.268616                -2.134652
# 1  1992-04-18           0.564487           1.345516                         0.683763                         1.346755                 6.195334
# 2  1992-07-18           0.253562          -0.093414                         0.091788                         0.437442                -3.204321
# 3  1992-10-18           0.057301           0.969470                        -0.560571                        -0.582929                 9.936041
# 4  1993-01-18           0.301254           1.270810                        -0.119211                         0.539610                 1.459880
#
#    housing_starts_growth_3  industrial_production_growth_1  industrial_production_growth_3  nonfarm_payrolls_diff_1  nonfarm_payrolls_diff_3  cpi_growth_1  \
# 0                 0.942514                       -0.185357                       -0.555043                     31.0                   -227.0      0.289855
# 1                19.961305                        0.280243                       -0.186393                     19.0                      4.0      0.503417
# 2               -13.823326                       -0.369004                        0.556072                   -117.0                    153.0      0.285511
# 3                 3.370644                       -0.275862                        0.092123                    -57.0                    -14.0      0.212691
# 4                 0.727276                        0.362648                        1.458549                     64.0                    214.0      0.070348
#
#    cpi_growth_3  business_inventories_diff_1  business_inventories_diff_3  news_sentiment_latest  news_sentiment_mean_30d  news_sentiment_mean_90d  \
# 0      0.799132                          NaN                          NaN              -0.008506                -0.066636                -0.091208
# 1      0.864559                          NaN                          NaN               0.053806                 0.081756                 0.061239
# 2      0.643549                          NaN                          NaN              -0.024632                 0.009692                 0.014894
# 3      0.639434                          NaN                          NaN              -0.062933                -0.059355                -0.012744
# 4      0.705719                          NaN                          NaN               0.186400                 0.231914                 0.104920
#
#    news_sentiment_momentum
# 0                 0.024572
# 1                 0.020517
# 2                -0.005202
# 3                -0.046610
# 4                 0.126994
#     cutoff_date  real_pce_growth_1  real_pce_growth_3  real_disposable_income_growth_1  real_disposable_income_growth_3  housing_starts_growth_1  \
# 134  2025-07-18          -0.277630           0.493561                        -0.690615                         0.583509                 4.489918
# 135  2025-10-18           0.349066           0.990578                         0.110022                         0.307148                -8.924046
# 136  2026-01-18           0.108379           0.913447                         0.053783                         0.433862                -4.703061
# 137  2026-04-18           0.103653           0.199013                        -0.453646                         0.122722                 6.961753
# 138  2026-07-18           0.261469           0.530816                         0.250539                        -0.377959                17.408646
#
#      housing_starts_growth_3  industrial_production_growth_1  industrial_production_growth_3  nonfarm_payrolls_diff_1  nonfarm_payrolls_diff_3  cpi_growth_1  \
# 134                -2.541243                        0.334092                        0.326375                    147.0                    449.0      0.286569
# 135                 1.931308                        0.097141                        0.253689                     22.0                     88.0      0.381722
# 136               -13.071845                        0.364406                        0.536103                     50.0                    -67.0      0.306884
# 137                15.617020                       -0.542979                        0.175515                    178.0                    205.0      0.861423
# 138                -6.445092                        0.076901                        1.001004                     57.0                    334.0     -0.423377
#
#      cpi_growth_3  business_inventories_diff_1  business_inventories_diff_3  news_sentiment_latest  news_sentiment_mean_30d  news_sentiment_mean_90d  \
# 134      0.588040                        649.0                       3157.0              -0.024331                -0.064511                -0.078981
# 135      0.864677                       5712.0                      10631.0              -0.154798                -0.066098                -0.012536
# 136      0.821078                       7240.0                      13002.0               0.025465                 0.023208                -0.043676
# 137      1.298767                      -1716.0                      -1594.0              -0.201432                -0.197266                -0.061228
# 138      0.686421                       8016.0                      49869.0               0.109474                 0.031715                -0.049440
#
#      news_sentiment_momentum
# 134                 0.014471
# 135                -0.053562
# 136                 0.066884
# 137                -0.136038
# 138                 0.081155

# %% [markdown]
# ## 9. Processed-feature diagnostics
#
# These diagnostics matter more for modeling than the raw snapshot alone.
#
# We inspect:
#
# - number of quarters vs number of features,
# - missingness after transformation,
# - distributions,
# - zero/low-variance features,
# - high pairwise correlations.
#
# This is the stage that tells us whether manual reduction, Ridge, PCA, or PLS is likely to be useful.

# %%
# Reload analysis after processed_features.csv has been created/updated.
processed_analysis = DataAnalysis.DataAnalysis()

display(processed_analysis.dimensionality_summary())
# Out:
#    n_observations  n_features  observations_per_feature
# 0             139          18                  7.722222

# %%
missing_summary = processed_analysis.processed_missing_summary()

display(missing_summary)

print("\nFeatures with > 20% missing values:")
display(
    missing_summary[
        missing_summary["missing_pct"] > 20
    ]
)
# Out:
#                             feature  n_missing  missing_pct
# 0       business_inventories_diff_3         20    14.388489
# 1       business_inventories_diff_1         20    14.388489
# 2                 real_pce_growth_1          0     0.000000
# 3                 real_pce_growth_3          0     0.000000
# 4           news_sentiment_mean_90d          0     0.000000
# 5           news_sentiment_mean_30d          0     0.000000
# 6             news_sentiment_latest          0     0.000000
# 7                      cpi_growth_3          0     0.000000
# 8                      cpi_growth_1          0     0.000000
# 9           nonfarm_payrolls_diff_3          0     0.000000
# 10          nonfarm_payrolls_diff_1          0     0.000000
# 11   industrial_production_growth_3          0     0.000000
# 12   industrial_production_growth_1          0     0.000000
# 13          housing_starts_growth_3          0     0.000000
# 14          housing_starts_growth_1          0     0.000000
# 15  real_disposable_income_growth_3          0     0.000000
# 16  real_disposable_income_growth_1          0     0.000000
# 17          news_sentiment_momentum          0     0.000000
# Features with > 20% missing values:
# Empty DataFrame
# Columns: [feature, n_missing, missing_pct]
# Index: []

# %%
distribution_summary = processed_analysis.processed_distribution_summary()

display(distribution_summary)
# Out:
#                                  count          mean           std           min            1%            5%          25%           50%           75%  \
# real_pce_growth_1                139.0      0.270041      0.717360     -1.232540     -0.856610     -0.370980     0.059015      0.219799      0.435132
# real_pce_growth_3                139.0      0.666843      1.328787    -11.882717     -0.604405     -0.071007     0.358036      0.753604      1.016123
# real_disposable_income_growth_1  139.0      0.105556      1.119554     -8.542327     -4.509988     -0.573575    -0.018176      0.223560      0.410051
# real_disposable_income_growth_3  139.0      0.595290      1.250774     -5.614553     -4.233408     -0.772900     0.243535      0.624289      0.964035
# housing_starts_growth_1          139.0     -0.026237      8.364912    -25.478786    -23.581747    -14.218187    -5.174362      0.793655      5.085416
# housing_starts_growth_3          139.0     -0.133210      9.997177    -31.217954    -28.269656    -16.558533    -5.159417      0.942514      5.194116
# industrial_production_growth_1   139.0      0.116082      0.883512     -5.552214     -2.538374     -0.756020    -0.192331      0.228468      0.460263
# industrial_production_growth_3   139.0      0.435349      1.440292     -6.941382     -5.417963     -1.576285    -0.115912      0.624974      1.283083
# nonfarm_payrolls_diff_1          139.0    156.532374    448.554010   -701.000000   -610.180000   -141.900000    26.500000    146.000000    222.500000
# nonfarm_payrolls_diff_3          139.0    346.000000   1305.510450 -13288.000000  -1855.880000   -273.800000   245.000000    495.000000    637.000000
# cpi_growth_1                     139.0      0.212522      0.305563     -0.739610     -0.466379     -0.204411     0.051525      0.199933      0.346553
# cpi_growth_3                     139.0      0.628938      0.643281     -3.403977     -0.580805     -0.211813     0.376982      0.624082      0.860696
# business_inventories_diff_1      119.0   4547.151261   8732.037382 -46011.000000 -19121.800000  -8928.400000  2149.500000   5070.000000   8225.000000
# business_inventories_diff_3      119.0  13533.941176  24650.346343 -80092.000000 -58713.300000 -15344.900000  5091.500000  13347.000000  21872.000000
# news_sentiment_latest            139.0      0.024236      0.190469     -0.587541     -0.486554     -0.280600    -0.103545      0.053806      0.164804
# news_sentiment_mean_30d          139.0      0.025533      0.187716     -0.558208     -0.480222     -0.286451    -0.103686      0.059705      0.158781
# news_sentiment_mean_90d          139.0      0.034319      0.173985     -0.599322     -0.386864     -0.269849    -0.071157      0.048790      0.164408
# news_sentiment_momentum          139.0     -0.008786      0.069792     -0.341693     -0.176369     -0.121567    -0.049122     -0.007938      0.042351
#
#                                           95%            99%            max  missing_pct  skewness   kurtosis
# real_pce_growth_1                    0.704309       0.925630       7.759898     0.000000  8.228456  87.177280
# real_pce_growth_3                    1.351357       3.241522       7.562316     0.000000 -5.036964  63.039311
# real_disposable_income_growth_1      1.006441       1.745810       5.117861     0.000000 -3.794456  31.767187
# real_disposable_income_growth_3      2.129704       4.706465       5.825244     0.000000 -0.684829   9.913050
# housing_starts_growth_1             12.620177      17.584989      19.652371     0.000000 -0.447326   0.588191
# housing_starts_growth_3             14.647437      22.711305      31.054021     0.000000 -0.300515   1.199646
# industrial_production_growth_1       0.891614       1.510459       5.272396     0.000000 -0.902100  20.183194
# industrial_production_growth_3       2.076168       2.947223       3.916275     0.000000 -1.977313   7.707593
# nonfarm_payrolls_diff_1            382.700000     890.920000    4800.000000     0.000000  8.062501  84.254506
# nonfarm_payrolls_diff_3           1097.900000    1695.540000    3911.000000     0.000000 -8.281145  87.574238
# cpi_growth_1                         0.707150       1.226780       1.313580     0.000000  0.688938   2.665360
# cpi_growth_3                         1.419550       2.498525       2.670657     0.000000 -1.148698  11.725254
# business_inventories_diff_1      13166.900000   32003.300000   33614.000000    14.388489 -1.359646  11.033317
# business_inventories_diff_3      43693.700000  105177.500000  118614.000000    14.388489  0.350842   6.544029
# news_sentiment_latest                0.295325       0.380316       0.410168     0.000000 -0.520838   0.141961
# news_sentiment_mean_30d              0.281284       0.352186       0.392370     0.000000 -0.544031   0.040471
# news_sentiment_mean_90d              0.284485       0.326086       0.342397     0.000000 -0.627938   0.456296
# news_sentiment_momentum              0.087346       0.137087       0.161965     0.000000 -0.828923   2.912798

# %%
#maye here plot a correlation matrices 

high_corr = processed_analysis.high_correlations(
    threshold=0.85
)

print(
    "Number of feature pairs with |correlation| >= 0.85:",
    len(high_corr)
)

display(high_corr.head(50))
# Out:
# Number of feature pairs with |correlation| >= 0.85: 5
#                      feature_1                    feature_2  correlation  abs_correlation
# 0        news_sentiment_latest      news_sentiment_mean_30d     0.975792         0.975792
# 1      news_sentiment_mean_30d      news_sentiment_mean_90d     0.928315         0.928315
# 2  business_inventories_diff_1  business_inventories_diff_3     0.903754         0.903754
# 3        news_sentiment_latest      news_sentiment_mean_90d     0.877143         0.877143
# 4            real_pce_growth_3      nonfarm_payrolls_diff_3     0.870357         0.870357

# %% [markdown]
# ### Visualize a manageable subset of feature distributions
#
# Instead of drawing every feature immediately, plot the six features with the largest absolute skewness. These are often the most useful distributions to inspect first for extreme values or transformation issues.

# %%
#maybe plot here features distributions 

if not distribution_summary.empty:

    skew_table = distribution_summary.copy()

    skew_table["abs_skewness"] = (
        skew_table["skewness"].abs()
    )

    features_to_plot = (
        skew_table
        .sort_values(
            "abs_skewness",
            ascending=False
        )
        .head(6)
        .index
        .tolist()
    )

    print("Features selected for distribution plots:")
    print(features_to_plot)

    for feature in features_to_plot:
        processed_analysis.plot_feature_distribution(
            feature
        )
# Out:
# Features selected for distribution plots:
# ['nonfarm_payrolls_diff_3', 'real_pce_growth_1', 'nonfarm_payrolls_diff_1', 'real_pce_growth_3', 'real_disposable_income_growth_1', 'industrial_production_growth_3']

# %% [markdown]
# ## 10. Create the final modeling dataset (Possible to make it run from here if we do not want to laod the data)

# %%
# %load_ext autoreload
# %autoreload 2

import config
import DataCollection
import DataProcessing
import DataAnalysis
import DataSplitter

import pandas as pd
import matplotlib.pyplot as plt

dataprocess = DataProcessing.DataProcessing()
TEST_SIZE = 0.10

# %%
# ==================================================
# Choose target
# ==================================================

TARGET_TYPE = "annualized_growth"

# Possible values:
# "level"
# "difference"
# "pct_change"
# "log_growth"
# "annualized_log_growth"
# "annualized_growth"

labels_df = dataprocess.build_labels(
    label_type=TARGET_TYPE
)

print(
    f"Target type: {TARGET_TYPE}"
)

display(
    labels_df.head()
)

final_df = dataprocess.create_final_df()

print(
    "Final dataset shape:",
    final_df.shape
)

display(
    final_df.head()
)

display(
    final_df.tail()
)
# Out:
# Target type: annualized_growth
#   quarter_end  gdp_initial  initial_growth cutoff_date  last_quarter_gdp  \
# 0  1991-12-31     1.000000        0.296461  1992-01-18               NaN
# 1  1992-03-31     1.004910        1.978356  1992-04-18          1.000000
# 2  1992-06-30     1.008374        1.385975  1992-07-18          1.004910
# 3  1992-09-30     1.014990        2.650422  1992-10-18          1.008374
# 4  1992-12-31     1.024474        3.790272  1993-01-18          1.014990
#
#      target
# 0  0.296461
# 1  1.978356
# 2  1.385975
# 3  2.650422
# 4  3.790272
# Final dataset shape: (139, 24)
#   cutoff_date  real_pce_growth_1  real_pce_growth_3  \
# 0  1992-01-18           0.360790           0.287304
# 1  1992-04-18           0.564487           1.345516
# 2  1992-07-18           0.253562          -0.093414
# 3  1992-10-18           0.057301           0.969470
# 4  1993-01-18           0.301254           1.270810
#
#    real_disposable_income_growth_1  real_disposable_income_growth_3  \
# 0                        -0.451991                        -0.268616
# 1                         0.683763                         1.346755
# 2                         0.091788                         0.437442
# 3                        -0.560571                        -0.582929
# 4                        -0.119211                         0.539610
#
#    housing_starts_growth_1  housing_starts_growth_3  \
# 0                -2.134652                 0.942514
# 1                 6.195334                19.961305
# 2                -3.204321               -13.823326
# 3                 9.936041                 3.370644
# 4                 1.459880                 0.727276
#
#    industrial_production_growth_1  industrial_production_growth_3  \
# 0                       -0.185357                       -0.555043
# 1                        0.280243                       -0.186393
# 2                       -0.369004                        0.556072
# 3                       -0.275862                        0.092123
# 4                        0.362648                        1.458549
#
#    nonfarm_payrolls_diff_1  ...  business_inventories_diff_3  \
# 0                     31.0  ...                          NaN
# 1                     19.0  ...                          NaN
# 2                   -117.0  ...                          NaN
# 3                    -57.0  ...                          NaN
# 4                     64.0  ...                          NaN
#
#    news_sentiment_latest  news_sentiment_mean_30d  news_sentiment_mean_90d  \
# 0              -0.008506                -0.066636                -0.091208
# 1               0.053806                 0.081756                 0.061239
# 2              -0.024632                 0.009692                 0.014894
# 3              -0.062933                -0.059355                -0.012744
# 4               0.186400                 0.231914                 0.104920
#
#    news_sentiment_momentum  quarter_end  gdp_initial  initial_growth  \
# 0                 0.024572   1991-12-31     1.000000        0.296461
# 1                 0.020517   1992-03-31     1.004910        1.978356
# 2                -0.005202   1992-06-30     1.008374        1.385975
# 3                -0.046610   1992-09-30     1.014990        2.650422
# 4                 0.126994   1992-12-31     1.024474        3.790272
#
#    last_quarter_gdp    target
# 0               NaN  0.296461
# 1          1.000000  1.978356
# 2          1.004910  1.385975
# 3          1.008374  2.650422
# 4          1.014990  3.790272
#
# [5 rows x 24 columns]
#     cutoff_date  real_pce_growth_1  real_pce_growth_3  \
# 134  2025-07-18          -0.277630           0.493561
# 135  2025-10-18           0.349066           0.990578
# 136  2026-01-18           0.108379           0.913447
# 137  2026-04-18           0.103653           0.199013
# 138  2026-07-18           0.261469           0.530816
#
#      real_disposable_income_growth_1  real_disposable_income_growth_3  \
# 134                        -0.690615                         0.583509
# 135                         0.110022                         0.307148
# 136                         0.053783                         0.433862
# 137                        -0.453646                         0.122722
# 138                         0.250539                        -0.377959
#
#      housing_starts_growth_1  housing_starts_growth_3  \
# 134                 4.489918                -2.541243
# 135                -8.924046                 1.931308
# 136                -4.703061               -13.071845
# 137                 6.961753                15.617020
# 138                17.408646                -6.445092
#
#      industrial_production_growth_1  industrial_production_growth_3  \
# 134                        0.334092                        0.326375
# 135                        0.097141                        0.253689
# 136                        0.364406                        0.536103
# 137                       -0.542979                        0.175515
# 138                        0.076901                        1.001004
#
#      nonfarm_payrolls_diff_1  ...  business_inventories_diff_3  \
# 134                    147.0  ...                       3157.0
# 135                     22.0  ...                      10631.0
# 136                     50.0  ...                      13002.0
# 137                    178.0  ...                      -1594.0
# 138                     57.0  ...                      49869.0
#
#      news_sentiment_latest  news_sentiment_mean_30d  news_sentiment_mean_90d  \
# 134              -0.024331                -0.064511                -0.078981
# 135              -0.154798                -0.066098                -0.012536
# 136               0.025465                 0.023208                -0.043676
# 137              -0.201432                -0.197266                -0.061228
# 138               0.109474                 0.031715                -0.049440
#
#      news_sentiment_momentum  quarter_end  gdp_initial  initial_growth  \
# 134                 0.014471   2025-06-30     2.190862        2.968252
# 135                -0.053562   2025-09-30     2.214270        4.342784
# 136                 0.066884   2025-12-31     2.222103        1.422544
# 137                -0.136038   2026-03-31     2.233075        1.989722
# 138                 0.081155   2026-06-30     2.241403        1.500152
#
#      last_quarter_gdp    target
# 134          2.174899  2.968252
# 135          2.190862  4.342784
# 136          2.214270  1.422544
# 137          2.222103  1.989722
# 138          2.233075  1.500152
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 11. Final target and alignment checks
#
# Before splitting, verify:
#
# - one row per cutoff,
# - chronological ordering,
# - no missing target values,
# - target distribution,
# - correct quarter alignment,
# - feature missingness is still allowed because the model pipeline will impute it later.

# %%
final_checks = pd.DataFrame({
    "metric": [
        "rows",
        "columns",
        "duplicate_cutoff_dates",
        "missing_target",
        "feature_nan_cells",
        "first_cutoff",
        "last_cutoff",
    ],
    "value": [
        final_df.shape[0],
        final_df.shape[1],
        final_df["cutoff_date"].duplicated().sum(),
        final_df["target"].isna().sum(),
        final_df.drop(columns=["cutoff_date", "target"]).isna().sum().sum(),
        final_df["cutoff_date"].min(),
        final_df["cutoff_date"].max(),
    ]
})

display(final_checks)

assert final_df["cutoff_date"].is_monotonic_increasing
assert final_df["cutoff_date"].duplicated().sum() == 0

# Manually inspect target alignment for a few rows.

display(
    final_df[
        [
            "cutoff_date",
            "target"
        ]
    ].head(10)
)
# Out:
#                    metric                value
# 0                    rows                  139
# 1                 columns                   24
# 2  duplicate_cutoff_dates                    0
# 3          missing_target                    0
# 4       feature_nan_cells                   41
# 5            first_cutoff  1992-01-18 00:00:00
# 6             last_cutoff  2026-07-18 00:00:00
#   cutoff_date    target
# 0  1992-01-18  0.296461
# 1  1992-04-18  1.978356
# 2  1992-07-18  1.385975
# 3  1992-10-18  2.650422
# 4  1993-01-18  3.790272
# 5  1993-04-18  1.799303
# 6  1993-07-18  1.577276
# 7  1993-10-18  2.844373
# 8  1994-01-18  5.870053
# 9  1994-04-18  2.581260

# %%
final_analysis = DataAnalysis.DataAnalysis()

display(final_analysis.target_summary(
    target_col="target"
))

display(final_analysis.target_extremes(
    target_col="target",
    n=8
))
# Out:
#    n_observations  n_missing  missing_pct      mean       std        min  \
# 0             139          0          0.0  2.456459  4.450608 -32.904137
#
#      median        max  skewness  kurtosis
# 0  2.566653  33.081827 -1.365339  44.31485
#     cutoff_date     target
# 114  2020-07-18 -32.904137
# 69   2009-04-18  -6.143680
# 113  2020-04-18  -4.783095
# 68   2009-01-18  -3.803667
# 121  2022-04-18  -1.414108
# 70   2009-07-18  -1.017341
# 122  2022-07-18  -0.934183
# 39   2001-10-18  -0.354922
# 115  2020-10-18  33.081827
# 47   2003-10-18   7.154641
# 120  2022-01-18   6.887441
# 118  2021-07-18   6.503091
# 117  2021-04-18   6.386402
# 8    1994-01-18   5.870053
# 41   2002-04-18   5.835609
# 32   2000-01-18   5.797983

# %%
plt.figure(figsize=(12, 4))

plt.plot(
    pd.to_datetime(final_df["cutoff_date"]),
    final_df["target"]
)

plt.title("Model target through time — initial-release GDP level")
plt.xlabel("Quarter-end cutoff")
plt.ylabel("Initial GDP level")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Chronological train/test split

# %%
datasplitter = DataSplitter.DataSplitter(
    final_df,
    target_col="target",
    date_col="cutoff_date",
    test_size=TEST_SIZE
)

(
    X_train,
    X_test,
    y_train,
    y_test,
    dates_train,
    dates_test
) = datasplitter.train_test_split()


# --------------------------------------------------
# Remove COVID period from TRAIN only
# --------------------------------------------------
cutoff_days = 18

dates_train = pd.to_datetime(dates_train)
covid_start = pd.Timestamp("2020-01-01") + pd.Timedelta(days=cutoff_days)
covid_end   = pd.Timestamp("2020-09-30") + pd.Timedelta(days=cutoff_days)


keep_mask = ~(
    (dates_train >= covid_start)
    & (dates_train <= covid_end)
)

X_train = X_train.loc[keep_mask].reset_index(drop=True)
y_train = y_train.loc[keep_mask].reset_index(drop=True)

dates_train = (
    dates_train.loc[keep_mask]
    .reset_index(drop=True)
)


# --------------------------------------------------
# Checks
# --------------------------------------------------

print("X_train:", X_train.shape)
print("X_test :", X_test.shape)

print("y_train:", y_train.shape)
print("y_test :", y_test.shape)

print(
    "\nTrain period:",
    dates_train.min(),
    "->",
    dates_train.max()
)

print(
    "Test period :",
    pd.to_datetime(dates_test).min(),
    "->",
    pd.to_datetime(dates_test).max()
)

print(
    "\nMissing y_train:",
    y_train.isna().sum()
)

print(
    "Missing y_test :",
    y_test.isna().sum()
)

print(
    "Missing X_train cells:",
    X_train.isna().sum().sum()
)

print(
    "Missing X_test cells :",
    X_test.isna().sum().sum()
)
# Out:
# X_train: (122, 18)
# X_test : (14, 18)
# y_train: (122,)
# y_test : (14,)
#
# Train period: 1992-01-18 00:00:00 -> 2023-01-18 00:00:00
# Test period : 2023-04-18 00:00:00 -> 2026-07-18 00:00:00
#
# Missing y_train: 0
# Missing y_test : 0
# Missing X_train cells: 40
# Missing X_test cells : 0

# %%
train_missing = pd.DataFrame({
    "n_missing": X_train.isna().sum(),
    "missing_pct": 100 * X_train.isna().mean()
}).sort_values(
    "missing_pct",
    ascending=False
)

display(train_missing)
# Out:
#                                  n_missing  missing_pct
# business_inventories_diff_3             20    16.393443
# business_inventories_diff_1             20    16.393443
# real_pce_growth_1                        0     0.000000
# real_pce_growth_3                        0     0.000000
# news_sentiment_mean_90d                  0     0.000000
# news_sentiment_mean_30d                  0     0.000000
# news_sentiment_latest                    0     0.000000
# cpi_growth_3                             0     0.000000
# cpi_growth_1                             0     0.000000
# nonfarm_payrolls_diff_3                  0     0.000000
# nonfarm_payrolls_diff_1                  0     0.000000
# industrial_production_growth_3           0     0.000000
# industrial_production_growth_1           0     0.000000
# housing_starts_growth_3                  0     0.000000
# housing_starts_growth_1                  0     0.000000
# real_disposable_income_growth_3          0     0.000000
# real_disposable_income_growth_1          0     0.000000
# news_sentiment_momentum                  0     0.000000

# %%
print(X_train.columns)
# Out:
# Index(['real_pce_growth_1', 'real_pce_growth_3',
#        'real_disposable_income_growth_1', 'real_disposable_income_growth_3',
#        'housing_starts_growth_1', 'housing_starts_growth_3',
#        'industrial_production_growth_1', 'industrial_production_growth_3',
#        'nonfarm_payrolls_diff_1', 'nonfarm_payrolls_diff_3', 'cpi_growth_1',
#        'cpi_growth_3', 'business_inventories_diff_1',
#        'business_inventories_diff_3', 'news_sentiment_latest',
#        'news_sentiment_mean_30d', 'news_sentiment_mean_90d',
#        'news_sentiment_momentum'],
#       dtype='object')

# %% [markdown]
# ## 13. Stop and review before dimensionality reduction
#
# At this point, inspect these outputs before deciding on PCA:
#
# 1. `dimensionality_summary()`
# 2. `processed_missing_summary()`
# 3. `high_correlations()`
# 4. train-only missingness
# 5. target distribution
# 6. raw feature coverage
#
# A sensible sequence for the **level target** is:
#
# ```text
# Persistence benchmark: GDP_t ≈ GDP_(t-1)
#     ↓
# Ridge with previous-quarter GDP anchor
#     ↓
# manual redundancy reduction
#     ↓
# PCA + Ridge
#     ↓
# possibly PLS
#     ↓
# tree models as comparison
# ```
#
# Do **not** fit PCA on `final_df` here. PCA belongs inside the cross-validation pipeline.

# %% [markdown]
# ## 14. Optional model training
#
# Keep this disabled while you are still diagnosing the data. When ready, switch `RUN_MODEL = True`.
#
# Start with Ridge because it is well suited to a small quarterly sample with correlated macroeconomic predictors.

# %%
RUN_MODEL = True
MODEL_TYPE = "lasso"

if RUN_MODEL:

    import TrainingModels
    import AnalyseModels

    trainer = TrainingModels.TrainingModels(
        X_train=X_train,
        y_train=y_train,
        model_type=MODEL_TYPE,
        n_splits=5,
        dates_train=dates_train,
        random_state=42,
        pca_bool = False
    )

    best_model = trainer.tune(
        n_trials=50
    )

    print(
        "CV score:",
        trainer.get_cv_score()
    )

    oof_predictions = (
        trainer.create_oof_predictions()
    )

    display(oof_predictions.head())

    analysis = AnalyseModels.AnalyseModels(
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        y_test=y_test,
        model_type=MODEL_TYPE,
        label_type=TARGET_TYPE,
        dates_train=dates_train,
        dates_test=dates_test
    )

    display(
        analysis.metrics()
    )
            
    if(MODEL_TYPE in ["linear","ridge","lasso","elasticnet"]):
        display(
            analysis.feature_coefficients()
        )
    analysis.plot_predictions()
else:
    print(
        "Model training is disabled. "
        "Review the diagnostics above first."
    )
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/best_model.pkl
#
# Model: lasso
# CV RMSE: 1.5712 +/- 0.2567
# Best parameters: {'alpha': 0.23493632958938304}
# CV score: {'rmse_mean': 1.5712274313917907, 'rmse_std': 0.2566601566511611}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/oof_predictions.csv
#    row_index    y_true    y_pred  fold cutoff_date     error  absolute_error  \
# 0         22  2.163327  3.732224     1  1997-07-18 -1.568897        1.568897
# 1         23  3.520602  4.471041     1  1997-10-18 -0.950439        0.950439
# 2         24  4.298257  4.400425     1  1998-01-18 -0.102169        0.102169
# 3         25  4.241671  2.103849     1  1998-04-18  2.137822        2.137822
# 4         26  1.416765  1.752743     1  1998-07-18 -0.335978        0.335978
#
#    squared_error
# 0       2.461439
# 1       0.903334
# 2       0.010438
# 3       4.570284
# 4       0.112881
#    model     sample       MAE      RMSE        R2    MAPE_pct
# 0  lasso      train  1.023540  1.377500  0.505667   96.104714
# 1  lasso  OOF_train  1.172912  1.592052  0.388198  118.300703
# 2  lasso       test  1.141321  1.291714 -0.018654  102.891803
#     rank                          feature  coefficient  abs_coefficient  \
# 0      1   industrial_production_growth_3     0.541396         0.541396
# 1      2                real_pce_growth_3     0.509016         0.509016
# 2      3          news_sentiment_mean_30d     0.260769         0.260769
# 3      4          nonfarm_payrolls_diff_3     0.149999         0.149999
# 4      5          nonfarm_payrolls_diff_1     0.031624         0.031624
# 5      6  real_disposable_income_growth_1    -0.016833         0.016833
# 6      7                     cpi_growth_3     0.000000         0.000000
# 7      8          news_sentiment_mean_90d     0.000000         0.000000
# 8      9            news_sentiment_latest     0.000000         0.000000
# 9     10      business_inventories_diff_3    -0.000000         0.000000
# 10    11      business_inventories_diff_1     0.000000         0.000000
# 11    12                real_pce_growth_1    -0.000000         0.000000
# 12    13                     cpi_growth_1     0.000000         0.000000
# 13    14   industrial_production_growth_1     0.000000         0.000000
# 14    15          housing_starts_growth_3     0.000000         0.000000
# 15    16          housing_starts_growth_1     0.000000         0.000000
# 16    17  real_disposable_income_growth_3     0.000000         0.000000
# 17    18          news_sentiment_momentum     0.000000         0.000000
#
#     selected
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False

# %%
import ModelsComparaisons

model_types = [
    "dumb_model",
    "linear",
    "ridge",
    "lasso",
    "elasticnet",
    "xgb",
    "catboost"
]

models_comparison = (
    ModelsComparaisons.ModelsComparaisons(
        model_types=model_types,
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        y_test=y_test,
        dates_train=dates_train,
        label_type="annualized_log_growth"
    )
)

comparison = (
    models_comparison
    .run_all(
        n_trials=50,
        n_splits=5,
        pca_bool=False
    )
)

display(comparison)

models_comparison.compare_pca(
    n_trials=50,
    n_splits=5
)

pca_table = (
    models_comparison.build_pca_comparison_df()
)

display(
    pca_table
)
# Out:
# ============================================================
# TRAINING MODEL: LINEAR
# ============================================================
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/linear/best_model.pkl
#
# Model: linear
# CV RMSE: 13.0411 +/- 22.0964
# Best parameters: {}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/linear/oof_predictions.csv
#
# ============================================================
# TRAINING MODEL: RIDGE
# ============================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/ridge/best_model.pkl
#
# Model: ridge
# CV RMSE: 1.7718 +/- 0.4236
# Best parameters: {'alpha': 2.3885957154942545}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/ridge/oof_predictions.csv
#
# ============================================================
# TRAINING MODEL: LASSO
# ============================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/best_model.pkl
#
# Model: lasso
# CV RMSE: 1.5712 +/- 0.2567
# Best parameters: {'alpha': 0.23493632958938304}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/oof_predictions.csv
#
# ============================================================
# TRAINING MODEL: ELASTICNET
# ============================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/elasticnet/best_model.pkl
#
# Model: elasticnet
# CV RMSE: 1.5626 +/- 0.2321
# Best parameters: {'alpha': 0.4110411487412925, 'l1_ratio': 0.5618014344591211}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/elasticnet/oof_predictions.csv
#
# ============================================================
# TRAINING MODEL: XGB
# ============================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/xgb/best_model.pkl
#
# Model: xgb
# CV RMSE: 1.6303 +/- 0.2767
# Best parameters: {'n_estimators': 275, 'max_depth': 4, 'learning_rate': 0.018385820877160407, 'subsample': 0.812575401709342, 'colsample_bytree': 0.7784259762664064, 'min_child_weight': 3, 'reg_alpha': 0.0005182009885657633, 'reg_lambda': 2.207208158287309e-07}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/xgb/oof_predictions.csv
#
# ============================================================
# TRAINING MODEL: CATBOOST
# ============================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/catboost/best_model.pkl
#
# Model: catboost
# CV RMSE: 1.6348 +/- 0.2783
# Best parameters: {'iterations': 612, 'depth': 2, 'learning_rate': 0.01291483690989417, 'l2_leaf_reg': 0.0031271762013649774}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/catboost/oof_predictions.csv
#
# ============================================================
# ALL MODELS TRAINED
# ============================================================
# Analysing dumb_model...
# Analysing linear...
# Analysing ridge...
# Analysing lasso...
# Analysing elasticnet...
# Analysing xgb...
# Analysing catboost...
#
# Comparison table saved to:
# /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/models_comparison.csv
#         Model  Train MAE  Train RMSE  Train R2  OOF MAE  OOF RMSE   OOF R2  Test MAE  Test RMSE  Test R2
# 0  elasticnet      1.043       1.399     0.490    1.144     1.580    0.398     1.122      1.283   -0.006
# 1       lasso      1.024       1.377     0.506    1.173     1.592    0.388     1.141      1.292   -0.019
# 2         xgb      0.227       0.296     0.977    1.208     1.654    0.340     1.201      1.520   -0.411
# 3    catboost      0.630       0.775     0.844    1.190     1.658    0.336     1.220      1.420   -0.232
# 4       ridge      0.974       1.285     0.570    1.354     1.822    0.199     1.072      1.286   -0.010
# 5  dumb_model      2.796       3.228    -1.714    2.766     3.212   -1.491     2.403      2.688   -3.411
# 6      linear      0.981       1.283     0.571    9.730    25.658 -157.904     1.074      1.294   -0.023
# ======================================================================
# MODEL: LINEAR | PCA: False
# ======================================================================
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/linear/best_model.pkl
#
# Model: linear
# CV RMSE: 13.0411 +/- 22.0964
# Best parameters: {}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/linear/oof_predictions.csv
#
# ======================================================================
# MODEL: LINEAR | PCA: True
# ======================================================================
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/linear/best_model.pkl
#
# Model: linear
# CV RMSE: 2.9246 +/- 2.1082
# Best parameters: {}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/linear/oof_predictions.csv
#
# ======================================================================
# MODEL: RIDGE | PCA: False
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/ridge/best_model.pkl
#
# Model: ridge
# CV RMSE: 1.7718 +/- 0.4236
# Best parameters: {'alpha': 2.3885957154942545}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/ridge/oof_predictions.csv
#
# ======================================================================
# MODEL: RIDGE | PCA: True
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/ridge/best_model.pkl
#
# Model: ridge
# CV RMSE: 1.8247 +/- 0.3202
# Best parameters: {'alpha': 288.6375245342521}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/ridge/oof_predictions.csv
#
# ======================================================================
# MODEL: LASSO | PCA: False
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/best_model.pkl
#
# Model: lasso
# CV RMSE: 1.5712 +/- 0.2567
# Best parameters: {'alpha': 0.23493632958938304}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/oof_predictions.csv
#
# ======================================================================
# MODEL: LASSO | PCA: True
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/best_model.pkl
#
# Model: lasso
# CV RMSE: 1.7364 +/- 0.2263
# Best parameters: {'alpha': 0.48462991867491706}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/lasso/oof_predictions.csv
#
# ======================================================================
# MODEL: ELASTICNET | PCA: False
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/elasticnet/best_model.pkl
#
# Model: elasticnet
# CV RMSE: 1.5626 +/- 0.2321
# Best parameters: {'alpha': 0.4110411487412925, 'l1_ratio': 0.5618014344591211}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/elasticnet/oof_predictions.csv
#
# ======================================================================
# MODEL: ELASTICNET | PCA: True
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/elasticnet/best_model.pkl
#
# Model: elasticnet
# CV RMSE: 1.7333 +/- 0.2282
# Best parameters: {'alpha': 0.9301850838399944, 'l1_ratio': 0.3802425572793087}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/elasticnet/oof_predictions.csv
#
# ======================================================================
# MODEL: XGB | PCA: False
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/xgb/best_model.pkl
#
# Model: xgb
# CV RMSE: 1.6303 +/- 0.2767
# Best parameters: {'n_estimators': 275, 'max_depth': 4, 'learning_rate': 0.018385820877160407, 'subsample': 0.812575401709342, 'colsample_bytree': 0.7784259762664064, 'min_child_weight': 3, 'reg_alpha': 0.0005182009885657633, 'reg_lambda': 2.207208158287309e-07}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/xgb/oof_predictions.csv
#
# ======================================================================
# MODEL: CATBOOST | PCA: False
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best model saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/catboost/best_model.pkl
#
# Model: catboost
# CV RMSE: 1.6348 +/- 0.2783
# Best parameters: {'iterations': 612, 'depth': 2, 'learning_rate': 0.01291483690989417, 'l2_leaf_reg': 0.0031271762013649774}
# OOF predictions saved to: /Users/raphaelbreaud/Desktop/Project/QuantCubeProject/data/models/catboost/oof_predictions.csv
#          model  PCA  Train MAE  Train RMSE  Train R2  OOF MAE  OOF RMSE   OOF R2  Test MAE  Test RMSE  Test R2
# 0     catboost   No      0.630       0.775     0.844    1.190     1.658    0.336     1.220      1.420   -0.232
# 1   dumb_model  N/A      2.796       3.228    -1.714    2.766     3.212   -1.491     2.403      2.688   -3.411
# 2   elasticnet   No      1.043       1.399     0.490    1.144     1.580    0.398     1.122      1.283   -0.006
# 3   elasticnet  Yes      1.131       1.494     0.419    1.310     1.748    0.262     1.053      1.262    0.027
# 4        lasso   No      1.024       1.377     0.506    1.173     1.592    0.388     1.141      1.292   -0.019
# 5        lasso  Yes      1.129       1.500     0.414    1.318     1.751    0.260     1.050      1.261    0.030
# 6       linear   No      0.981       1.283     0.571    9.730    25.658 -157.904     1.074      1.294   -0.023
# 7       linear  Yes      1.030       1.351     0.524    2.119     3.605   -2.137     1.034      1.203    0.117
# 8        ridge   No      0.974       1.285     0.570    1.354     1.822    0.199     1.072      1.286   -0.010
# 9        ridge  Yes      1.110       1.467     0.439    1.363     1.853    0.172     0.999      1.213    0.102
# 10         xgb   No      0.227       0.296     0.977    1.208     1.654    0.340     1.201      1.520   -0.411

# %% [markdown]
# ### Benchmark note
#
# For the target used in this notebook — the **initial-release GDP level** — the natural persistence benchmark is:
#
# \[
# \widehat{GDP_t} = GDP_{t-1}
# \]
#
# So the dumb model should predict the previous observed GDP level, not zero.
#
# For a level-target model, it can also be useful to include `last_quarter_gdp` as an explicit predictor/anchor, provided it is constructed only from information available before the current-quarter target release.
#
# For evaluation, MAE and RMSE are especially useful. R² can also be reported, but because GDP level is strongly trending, always compare against the persistence benchmark.
